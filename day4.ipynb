# %% [markdown]
# <a href="https://colab.research.google.com/github/itzwow/FMML_August_AmitBera/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# series single dimension data
stocks = pd.Series(np.random.randn(1000))

# %%
stocks
# Out:
# 0      0.863769
# 1      0.385828
# 2     -1.199329
# 3     -1.261010
# 4      0.418073
#          ...
# 995   -0.206380
# 996    0.222850
# 997   -0.553707
# 998    0.468870
# 999   -0.463966
# Length: 1000, dtype: float64
# 0      0.863769
# 1      0.385828
# 2     -1.199329
# 3     -1.261010
# 4      0.418073
#          ...
# 995   -0.206380
# 996    0.222850
# 997   -0.553707
# 998    0.468870
# 999   -0.463966
# Length: 1000, dtype: float64

# %%
stocks.plot()

# %%
stocks.cumsum().plot()

# %%
stocks = pd.DataFrame(np.random.randn(1000,4))

# %%
stocks.cumsum().plot()
